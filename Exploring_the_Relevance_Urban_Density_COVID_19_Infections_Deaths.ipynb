# %% [markdown]
# <a href="https://colab.research.google.com/github/MC-Codingcat/NL-COVID-19-Data-Analysis/blob/main/Exploring_the_Relevance_Urban_Density_COVID_19_Infections_Deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploring the Relevance: Urban Density - COVID-19 Infections/Deaths**
# <br/><br/>
# # Summary
# This report presents an analysis of COVID-19 infections in the Netherlands. The report attempts to compare COVID data with spatial and socio-economic indicators (e.g., built density, average house value, sex, age) to explore the potential links between COVID infections and factors regarding the built environment and individuals' conditions.
# ###<br/><br/>
# # Methodology
# ### 1. Data collection
# The COVID infection data was obtained from RIVM (National Institute for Public Health and the Environment) and the regional (spatial) data from CBS (Statistics Netherlands). Both are public data sources in the Netherlands.
# ### 2. Exploratory Data Analysis (EDA)
# Exploratory analysis techniques were applied to understand the dataset's structure, distributions, and basic statistics.
# ### 3. Data Cleaning / Wrangling
# Data processing steps included handling missing values, data transformation and joining data tables based on key values (e.g., location).
# ### 4. Statistical Analysis
# Statistical methods were used to analyze infection patterns and identify correlations.
# ### 5. Visualizations
# Various visualizations were created to aid in understanding the data.
# ###<br/><br/>

# %% [markdown]
# ##Loading data

# %%
# data analysis and visualization libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# libraries for geographical and interactive plots
# !pip install cufflinks
import cufflinks as cf
# %matplotlib inline
cf.go_offline()

# allow reading data files from google drive
from google.colab import drive
drive.mount('/content/drive')

# filter warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading COVID data: num. of cases per municipality per day （cumulative）

# %%
path = '/content/drive/MyDrive/Colab Notebooks/NL Covid-19 analysis/COVID-19_aantallen_gemeente_cumulatief.csv'
col_names_gmcum = ['Version', 'Date_of_report', 'Date_of_publication', 'Municipality_code', 'Municipality_name', 'Province', 'Total_reported', 'Hospital_admission', 'Deceased']
df_gmcum = pd.read_csv(path, sep = ';', header = 0, names = col_names_gmcum)
df_gmcum.head(3)
# Out:
#    Version       Date_of_report  Date_of_publication Municipality_code  \
# 0        8  2020-03-13 10:00:00  2020-03-13 10:00:00            GM0003
# 1        8  2020-03-13 10:00:00  2020-03-13 10:00:00            GM0010
# 2        8  2020-03-13 10:00:00  2020-03-13 10:00:00            GM0014
#
#   Municipality_name   Province  Total_reported  Hospital_admission  Deceased
# 0        Appingedam  Groningen               0                   0         0
# 1          Delfzijl  Groningen               0                   0         0
# 2         Groningen  Groningen               3                   0         0

# %%
df_gmcum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403206 entries, 0 to 403205
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Version              403206 non-null  int64
#  1   Date_of_report       403206 non-null  object
#  2   Date_of_publication  403206 non-null  object
#  3   Municipality_code    389421 non-null  object
#  4   Municipality_name    389421 non-null  object
#  5   Province             402789 non-null  object
#  6   Total_reported       403206 non-null  int64
#  7   Hospital_admission   403206 non-null  int64
#  8   Deceased             403206 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 27.7+ MB

# %%
df_gmcum.describe()
# Out:
#         Version  Total_reported  Hospital_admission       Deceased
# count  403206.0   403206.000000       403206.000000  403206.000000
# mean        8.0    10509.478726         3912.204283     832.594860
# std         0.0    23978.530957         4842.704924    2690.152387
# min         8.0        0.000000            0.000000       0.000000
# 25%         8.0      667.000000           25.000000      11.000000
# 50%         8.0     3830.000000           78.000000      28.000000
# 75%         8.0    12302.000000         9999.000000      61.000000
# max         8.0   443708.000000         9999.000000    9999.000000

# %% [markdown]
# #### Cleaning the COVID data
# ####1- Drop the rows with empty cells

# %%
df_gmcum.isnull().sum()
# Out:
# Version                    0
# Date_of_report             0
# Date_of_publication        0
# Municipality_code      13785
# Municipality_name      13785
# Province                 417
# Total_reported             0
# Hospital_admission         0
# Deceased                   0
# dtype: int64

# %%
#check if the range of null values overlays
df_gmcum.dropna(subset=['Municipality_code']).isnull().sum()
# Out:
# Version                0
# Date_of_report         0
# Date_of_publication    0
# Municipality_code      0
# Municipality_name      0
# Province               0
# Total_reported         0
# Hospital_admission     0
# Deceased               0
# dtype: int64

# %%
#drop the cells without location info
df_gmcum.dropna(subset=['Municipality_code'], inplace=True)

# %% [markdown]
# ####2- Handling abnormal data
#
# The value "9999" in the columns reporting num. of patients deceased/admitted into hospitals is weird and needs to be checked out. This can be caused by delayed registration of cases or a system setup issue.

# %%
df_gmcum[df_gmcum['Hospital_admission']==9999]
# Out:
#         Version       Date_of_report  Date_of_publication Municipality_code  \
# 246964        8  2022-01-18 10:00:00  2022-01-18 10:00:00            GM0014
# 246965        8  2022-01-18 10:00:00  2022-01-18 10:00:00            GM0034
# 246966        8  2022-01-18 10:00:00  2022-01-18 10:00:00            GM0037
# 246967        8  2022-01-18 10:00:00  2022-01-18 10:00:00            GM0047
# 246968        8  2022-01-18 10:00:00  2022-01-18 10:00:00            GM0050
# ...         ...                  ...                  ...               ...
# 403188        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1979
# 403189        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1980
# 403190        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1982
# 403191        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1991
# 403192        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1992
#
#        Municipality_name       Province  Total_reported  Hospital_admission  \
# 246964         Groningen      Groningen           37282                9999
# 246965            Almere      Flevoland           44802                9999
# 246966       Stadskanaal      Groningen            5226                9999
# 246967           Veendam      Groningen            3871                9999
# 246968          Zeewolde      Flevoland            4001                9999
# ...                  ...            ...             ...                 ...
# 403188         Eemsdelta      Groningen           18120                9999
# 403189     Dijk en Waard  Noord-Holland           42413                9999
# 403190    Land van Cuijk  Noord-Brabant           49355                9999
# 403191         Maashorst  Noord-Brabant           30200                9999
# 403192    Voorne aan Zee   Zuid-Holland           30629                9999
#
#         Deceased
# 246964        63
# 246965       124
# 246966        23
# 246967        19
# 246968        17
# ...          ...
# 403188      9999
# 403189      9999
# 403190      9999
# 403191      9999
# 403192      9999
#
# [150569 rows x 9 columns]

# %%
df_gmcum[df_gmcum['Deceased']==9999]
# Out:
#         Version       Date_of_report  Date_of_publication Municipality_code  \
# 371256        8  2023-01-03 10:00:00  2023-01-01 10:00:00            GM0014
# 371257        8  2023-01-03 10:00:00  2023-01-01 10:00:00            GM0034
# 371258        8  2023-01-03 10:00:00  2023-01-01 10:00:00            GM0037
# 371259        8  2023-01-03 10:00:00  2023-01-01 10:00:00            GM0047
# 371260        8  2023-01-03 10:00:00  2023-01-01 10:00:00            GM0050
# ...         ...                  ...                  ...               ...
# 403188        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1979
# 403189        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1980
# 403190        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1982
# 403191        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1991
# 403192        8  2023-03-31 10:00:00  2023-03-31 10:00:00            GM1992
#
#        Municipality_name       Province  Total_reported  Hospital_admission  \
# 371256         Groningen      Groningen          110033                9999
# 371257            Almere      Flevoland           98656                9999
# 371258       Stadskanaal      Groningen           13553                9999
# 371259           Veendam      Groningen           11730                9999
# 371260          Zeewolde      Flevoland           10583                9999
# ...                  ...            ...             ...                 ...
# 403188         Eemsdelta      Groningen           18120                9999
# 403189     Dijk en Waard  Noord-Holland           42413                9999
# 403190    Land van Cuijk  Noord-Brabant           49355                9999
# 403191         Maashorst  Noord-Brabant           30200                9999
# 403192    Voorne aan Zee   Zuid-Holland           30629                9999
#
#         Deceased
# 371256      9999
# 371257      9999
# 371258      9999
# 371259      9999
# 371260      9999
# ...          ...
# 403188      9999
# 403189      9999
# 403190      9999
# 403191      9999
# 403192      9999
#
# [30780 rows x 9 columns]

# %% [markdown]
# <br><br/>
# It is unlikely that the municipalities all have 9999 admissions to hospitals and deceased patients within one day (even if the data is accumulative and there might be a delayed registration). Let's check the data of the days right before the appearance of the value 9999, and the total number of cases compared to the latest data.
# <br><br/>

# %%
df_gmcum[df_gmcum['Date_of_publication']=='2022-01-17 10:00:00']
# Out:
#         Version       Date_of_report  Date_of_publication Municipality_code  \
# 246600        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM0014
# 246601        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM0034
# 246602        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM0037
# 246603        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM0047
# 246604        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM0050
# ...         ...                  ...                  ...               ...
# 246947        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM1966
# 246948        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM1969
# 246949        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM1970
# 246950        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM1978
# 246951        8  2022-01-17 10:00:00  2022-01-17 10:00:00            GM1979
#
#         Municipality_name      Province  Total_reported  Hospital_admission  \
# 246600          Groningen     Groningen           36896                 142
# 246601             Almere     Flevoland           44409                 456
# 246602        Stadskanaal     Groningen            5213                  41
# 246603            Veendam     Groningen            3854                  21
# 246604           Zeewolde     Flevoland            3970                  27
# ...                   ...           ...             ...                 ...
# 246947       Het Hogeland     Groningen            8129                  51
# 246948     Westerkwartier     Groningen            8548                  47
# 246949  Noardeast-Fryslân       Fryslân            8846                  86
# 246950        Molenlanden  Zuid-Holland           11365                  65
# 246951          Eemsdelta     Groningen            5472                  59
#
#         Deceased
# 246600        63
# 246601       124
# 246602        23
# 246603        19
# 246604        17
# ...          ...
# 246947        37
# 246948        36
# 246949        57
# 246950        44
# 246951        29
#
# [352 rows x 9 columns]

# %%
df_gmcum[df_gmcum['Date_of_publication']=='2022-12-31 10:00:00']
# Out:
#         Version       Date_of_report  Date_of_publication Municipality_code  \
# 370901        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM0014
# 370902        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM0034
# 370903        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM0037
# 370904        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM0047
# 370905        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM0050
# ...         ...                  ...                  ...               ...
# 371238        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM1979
# 371239        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM1980
# 371240        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM1982
# 371241        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM1991
# 371242        8  2023-01-03 10:00:00  2022-12-31 10:00:00            GM1992
#
#        Municipality_name       Province  Total_reported  Hospital_admission  \
# 370901         Groningen      Groningen          110020                9999
# 370902            Almere      Flevoland           98654                9999
# 370903       Stadskanaal      Groningen           13552                9999
# 370904           Veendam      Groningen           11728                9999
# 370905          Zeewolde      Flevoland           10582                9999
# ...                  ...            ...             ...                 ...
# 371238         Eemsdelta      Groningen           18042                9999
# 371239     Dijk en Waard  Noord-Holland           42238                9999
# 371240    Land van Cuijk  Noord-Brabant           49113                9999
# 371241         Maashorst  Noord-Brabant           30077                9999
# 371242    Voorne aan Zee   Zuid-Holland           30512                9999
#
#         Deceased
# 370901        81
# 370902       133
# 370903        25
# 370904        20
# 370905        20
# ...          ...
# 371238        32
# 371239        77
# 371240       142
# 371241       128
# 371242        93
#
# [342 rows x 9 columns]

# %%
df_gmcum[df_gmcum['Date_of_publication']=='2022-12-31 10:00:00']['Deceased'].sum()
# Out:
# 22940

# %% [markdown]
# It can be seen from the tables that the data in the columns "Total_reported", "Hospital_admission", and "Deceased" are all accumulative. The accumulative death toll in October 2023 is 22992, so the data of 31-12-2022 is likely correct. Likewise, the last valid data of the number of admissions is the data of 17-01-2022. For some reason, the data afterward is lost. The data of total reported cases, however, is all valid in the dataset.
# <br><br/>

# %%
#change "9999" to "NaN"
df_gmcum['Hospital_admission'].replace(9999, np.nan , inplace=True)
df_gmcum['Deceased'].replace(9999, np.nan , inplace=True)

# %%
#export the timeline data for time series analysis (another sub-project)
df_gmcum.drop(['Date_of_publication','Municipality_code','Version'],axis=1).to_csv('/content/drive/MyDrive/Colab Notebooks/NL Covid-19 analysis/cumulative-gm.csv')

# %%
#delete the redundant columns and change the column name for clarification
df_gm_total = df_gmcum[df_gmcum['Date_of_publication']=='2023-03-31 10:00:00']
df_gm_total.drop(['Version','Date_of_report','Hospital_admission','Deceased'],axis=1,inplace=True)
df_dec = df_gmcum[df_gmcum['Date_of_publication']=='2022-12-31 10:00:00'][['Municipality_code','Deceased']]
df_gm_total = pd.merge(df_gm_total, df_dec, on='Municipality_code')
df_gm_total.rename({'Deceased' : 'Deceased_till_2022'},axis='columns',inplace=True)
df_gm_total.drop(['Date_of_publication','Municipality_code'],axis=1,inplace=True)

# %%
df_gm_total
# Out:
#     Municipality_name       Province  Total_reported  Deceased_till_2022
# 0           Groningen      Groningen          110430                81.0
# 1              Almere      Flevoland           98978               133.0
# 2         Stadskanaal      Groningen           13615                25.0
# 3             Veendam      Groningen           11773                20.0
# 4            Zeewolde      Flevoland           10615                20.0
# ..                ...            ...             ...                 ...
# 337         Eemsdelta      Groningen           18120                32.0
# 338     Dijk en Waard  Noord-Holland           42413                77.0
# 339    Land van Cuijk  Noord-Brabant           49355               142.0
# 340         Maashorst  Noord-Brabant           30200               128.0
# 341    Voorne aan Zee   Zuid-Holland           30629                93.0
#
# [342 rows x 4 columns]

# %% [markdown]
# By 2023 there are indeed 342 *gemeenten* (municipalities) in the Netherlands. The death toll data also makes sense.

# %% [markdown]
# ### Loading and cleaning regional data (per municipality)

# %%
df_gemeenten = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NL Covid-19 analysis/Gemeenten_kerncijfers_2023.csv', sep=';', header = 0)
df_gemeenten.head()
# Out:
#   Municipality  Population  Residents per km²  Homes per km²  \
# 0  Aa en Hunze     25724.0               93.0           41.0
# 1      Aalburg         NaN                NaN            NaN
# 2     Aalsmeer     33063.0             1645.0          670.0
# 3       Aalten     27244.0              282.0          126.0
# 4      Ter Aar         NaN                NaN            NaN
#
#    Num. all business  Num. Handel en horeca  Num. Gov, Edu and Care  \
# 0             3180.0                  500.0                   600.0
# 1                NaN                    NaN                     NaN
# 2             5065.0                 1040.0                   580.0
# 3             2965.0                  515.0                   460.0
# 4                NaN                    NaN                     NaN
#
#   Surface area (km²)
# 0             278,87
# 1                NaN
# 2              32,29
# 3              97,05
# 4                NaN

# %%
df_gemeenten['Municipality'].nunique()
# Out:
# 727

# %% [markdown]
# By 2023, there are 342 municipalities in the Netherlands. The table above contains way more rows (of "municipalities") than it should.

# %%
df_gemeenten.dropna(subset=['Num. all business'])['Municipality'].nunique()
# Out:
# 342

# %%
df_gemeenten.dropna(subset=['Num. all business'], inplace=True)
df_gemeenten
# Out:
#         Municipality  Population  Residents per km²  Homes per km²  \
# 0        Aa en Hunze     25724.0               93.0           41.0
# 2           Aalsmeer     33063.0             1645.0          670.0
# 3             Aalten     27244.0              282.0          126.0
# 7      Achtkarspelen     28149.0              275.0          120.0
# 9       Alblasserdam     20356.0             2320.0          963.0
# ..               ...         ...                ...            ...
# 720          Zundert     22518.0              187.0           82.0
# 721          Zutphen     48510.0             1186.0          571.0
# 722  Zwartewaterland     23368.0              284.0          112.0
# 725      Zwijndrecht     45018.0             2217.0         1026.0
# 726           Zwolle    132411.0             1196.0          546.0
#
#      Num. all business  Num. Handel en horeca  Num. Gov, Edu and Care  \
# 0               3180.0                  500.0                   600.0
# 2               5065.0                 1040.0                   580.0
# 3               2965.0                  515.0                   460.0
# 7               3225.0                  725.0                   365.0
# 9               2355.0                  455.0                   320.0
# ..                 ...                    ...                     ...
# 720             3120.0                  485.0                   325.0
# 721             5985.0                 1075.0                  1495.0
# 722             2615.0                  565.0                   270.0
# 725             5000.0                  835.0                   810.0
# 726            16395.0                 2760.0                  3605.0
#
#     Surface area (km²)
# 0               278,87
# 2                32,29
# 3                97,05
# 7               103,98
# 9                10,06
# ..                 ...
# 720             121,21
# 721              42,93
# 722              87,86
# 725              22,77
# 726             119,36
#
# [342 rows x 8 columns]

# %% [markdown]
# ### Transforming regional data

# %% [markdown]
# Transform all data of total counts to density

# %%
type(df_gemeenten['Surface area (km²)'].iloc[0])
# Out:
# str

# %%
df_gemeenten['Surface area (km²)'] = df_gemeenten['Surface area (km²)'].str.replace(',', '.')
df_gemeenten['Surface area (km²)'] = df_gemeenten['Surface area (km²)'].astype('float')
df_gemeenten['Population'] = df_gemeenten['Population'].astype('int32')
df_gemeenten['Residents per km²'] = df_gemeenten['Residents per km²'].astype('int32')

# %%
df_gemeenten['Density Business']=(df_gemeenten['Num. all business'] / df_gemeenten['Surface area (km²)']).round(decimals=2)
df_gemeenten['Density horeca']=(df_gemeenten['Num. Handel en horeca'] / df_gemeenten['Surface area (km²)']).round(decimals=2)
df_gemeenten['Density public']=(df_gemeenten['Num. Gov, Edu and Care'] / df_gemeenten['Surface area (km²)']).round(decimals=2)
df_gemeenten.drop(['Num. all business','Num. Handel en horeca','Num. Gov, Edu and Care'], axis=1, inplace=True)

# %% [markdown]
# Merge the location info with the infection data to make a whole list

# %%
df_gemeenten['Municipality'].replace('Beek (L.)', 'Beek', inplace=True)
df_gemeenten['Municipality'].replace("'s-Gravenhage (gemeente)", "'s-Gravenhage", inplace=True)
df_gemeenten['Municipality'].replace('Groningen (gemeente)', 'Groningen', inplace=True)
df_gemeenten['Municipality'].replace('Hengelo (O.)', 'Hengelo', inplace=True)
df_gemeenten['Municipality'].replace('Laren (NH.)', 'Laren', inplace=True)
df_gemeenten['Municipality'].replace('Middelburg (Z.)', 'Middelburg', inplace=True)
df_gemeenten['Municipality'].replace('Rijswijk (ZH.)', 'Rijswijk', inplace=True)
df_gemeenten['Municipality'].replace('Stein (L.)', 'Stein', inplace=True)
df_gemeenten['Municipality'].replace('Utrecht (gemeente)', 'Utrecht', inplace=True)

# %%
df = df_gm_total.merge(df_gemeenten, how='left', left_on='Municipality_name', right_on='Municipality')
df.drop(['Municipality_name'], axis=1, inplace=True)
df.isnull().sum()
# Out:
# Province              0
# Total_reported        0
# Deceased_till_2022    0
# Municipality          0
# Population            0
# Residents per km²     0
# Homes per km²         0
# Surface area (km²)    0
# Density Business      0
# Density horeca        0
# Density public        0
# dtype: int64

# %% [markdown]
# ### Getting the data for analysis (cumulative infections/deaths - municipalities)

# %%
#change the order of the columns so that the table looks tidier and more logical
df=df.iloc[:, [0,3,1,2,4,5,6,7,8,9,10]]
df.head()
# Out:
#     Province Municipality  Total_reported  Deceased_till_2022  Population  \
# 0  Groningen    Groningen          110430                81.0      238147
# 1  Flevoland       Almere           98978               133.0      222825
# 2  Groningen  Stadskanaal           13615                25.0       32135
# 3  Groningen      Veendam           11773                20.0       27616
# 4  Flevoland     Zeewolde           10615                20.0       23692
#
#    Residents per km²  Homes per km²  Surface area (km²)  Density Business  \
# 0               1284          661.0              197.96            147.53
# 1               1725          702.0              248.77            116.75
# 2                273          129.0              119.94             25.60
# 3                364          171.0               78.68             31.77
# 4                 96           38.0              268.86             12.87
#
#    Density horeca  Density public
# 0           23.44           28.87
# 1           19.60           22.89
# 2            5.63            3.71
# 3            6.86            5.21
# 4            2.25            1.97

# %% [markdown]
# <br><br/>
# ## Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#        Total_reported  Deceased_till_2022     Population  Residents per km²  \
# count      342.000000          342.000000     342.000000         342.000000
# mean     24936.461988           67.076023   52079.798246         910.959064
# std      37003.290802          105.988159   77013.747371        1077.661334
# min        279.000000            0.000000     982.000000          23.000000
# 25%      10589.500000           27.000000   23180.000000         248.250000
# 50%      15435.500000           44.000000   32504.500000         478.000000
# 75%      25193.500000           76.250000   52538.000000        1184.000000
# max     443708.000000         1185.000000  918117.000000        6827.000000
#
#        Homes per km²  Surface area (km²)  Density Business  Density horeca  \
# count     342.000000          342.000000        342.000000      342.000000
# mean      413.669591          121.471842        102.058947       16.800614
# std       506.589973          130.685066        129.336595       19.454688
# min        14.000000            7.840000          0.880000        0.250000
# 25%       106.000000           37.180000         26.712500        4.900000
# 50%       213.500000           81.480000         55.925000        9.150000
# 75%       542.000000          146.310000        121.160000       21.702500
# max      3278.000000          907.860000        935.690000      120.970000
#
#        Density public
# count      342.000000
# mean        17.528830
# std         24.098059
# min          0.110000
# 25%          3.977500
# 50%          8.425000
# 75%         21.347500
# max        153.030000

# %% [markdown]
# *  The municipalities with the most reported cases

# %%
df.nlargest(5,['Total_reported'])
# Out:
#           Province   Municipality  Total_reported  Deceased_till_2022  \
# 106  Noord-Holland      Amsterdam          443708              1127.0
# 164   Zuid-Holland      Rotterdam          318211              1185.0
# 147   Zuid-Holland  's-Gravenhage          245475               686.0
# 96         Utrecht        Utrecht          197884               327.0
# 222  Noord-Brabant        Tilburg          116242               310.0
#
#      Population  Residents per km²  Homes per km²  Surface area (km²)  \
# 106      918117               4880         2524.0              243.65
# 164      663900               3040         1471.0              324.14
# 147      562839               6827         3278.0               98.12
# 96       367947               3924         1764.0               99.21
# 222      227707               1809          836.0              128.46
#
#      Density Business  Density horeca  Density public
# 106            786.39          115.29          117.55
# 164            304.88           46.85           53.76
# 147            935.69          120.97          153.03
# 96             582.75           73.43          119.39
# 222            203.22           36.35           34.33

# %% [markdown]
# * The municipalities with the most deceased cases

# %%
df.nlargest(5,['Deceased_till_2022'])
# Out:
#           Province   Municipality  Total_reported  Deceased_till_2022  \
# 164   Zuid-Holland      Rotterdam          318211              1185.0
# 106  Noord-Holland      Amsterdam          443708              1127.0
# 147   Zuid-Holland  's-Gravenhage          245475               686.0
# 201  Noord-Brabant      Eindhoven          113626               451.0
# 96         Utrecht        Utrecht          197884               327.0
#
#      Population  Residents per km²  Homes per km²  Surface area (km²)  \
# 164      663900               3040         1471.0              324.14
# 106      918117               4880         2524.0              243.65
# 147      562839               6827         3278.0               98.12
# 201      243730               2769         1344.0               89.36
# 96       367947               3924         1764.0               99.21
#
#      Density Business  Density horeca  Density public
# 164            304.88           46.85           53.76
# 106            786.39          115.29          117.55
# 147            935.69          120.97          153.03
# 201            348.59           60.82           54.11
# 96             582.75           73.43          119.39

# %% [markdown]
# * The municipalities with the highest infection density

# %%
df['Infected per k'] =  df.apply(lambda row: round(row.Total_reported/row.Population*1000), axis=1)
df.nlargest(5, ['Infected per k'])[['Infected per k','Municipality']]
# Out:
#      Infected per k       Municipality
# 87              591         Bunschoten
# 295             585     Rijssen-Holten
# 183             561        Reimerswaal
# 253             552  Horst aan de Maas
# 40              544            Wierden

# %% [markdown]
# * The municipalities with the highest mortality rate

# %%
df['Death per k'] = df.apply(lambda row: row.Deceased_till_2022/row.Population*1000, axis=1)
df.nlargest(5, ['Death per k'])[['Death per k','Municipality']]
# Out:
#      Death per k            Municipality
# 279     2.973478             Cranendonck
# 136     2.907308               Zandvoort
# 153     2.745390  Krimpen aan den IJssel
# 231     2.743779               Landgraaf
# 125     2.732240                   Laren

# %%
ax = sns.barplot(data=df, x='Province',y='Total_reported',palette='BuPu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
plt.tight_layout()

# %%
ax = sns.barplot(data=df, x='Province',y='Deceased_till_2022',palette='BuPu')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()

# %%
sns.boxplot(y=df['Province'], x=df['Infected per k'],palette='BuPu')
# Out:
# <Axes: xlabel='Infected per k', ylabel='Province'>

# %%
sns.boxplot(y=df['Province'], x=df['Death per k'],palette='BuPu')
# Out:
# <Axes: xlabel='Death per k', ylabel='Province'>

# %% [markdown]
# <br><br/>

# %% [markdown]
# ##Exploring the correlation between spatial factors and covid infection and deaths

# %%
df.corr()
# Out:
#                     Total_reported  Deceased_till_2022  Population  \
# Total_reported            1.000000            0.944219    0.997710
# Deceased_till_2022        0.944219            1.000000    0.944817
# Population                0.997710            0.944817    1.000000
# Residents per km²         0.502267            0.487437    0.504803
# Homes per km²             0.524450            0.511998    0.528100
# Surface area (km²)        0.113094            0.078135    0.127218
# Density Business          0.575487            0.544175    0.576169
# Density horeca            0.551875            0.532084    0.550910
# Density public            0.541091            0.504463    0.539017
# Infected per k            0.088909            0.087339    0.051763
# Death per k              -0.010327            0.188722   -0.019306
#
#                     Residents per km²  Homes per km²  Surface area (km²)  \
# Total_reported               0.502267       0.524450            0.113094
# Deceased_till_2022           0.487437       0.511998            0.078135
# Population                   0.504803       0.528100            0.127218
# Residents per km²            1.000000       0.996632           -0.333972
# Homes per km²                0.996632       1.000000           -0.319410
# Surface area (km²)          -0.333972      -0.319410            1.000000
# Density Business             0.959451       0.962052           -0.326408
# Density horeca               0.963832       0.965198           -0.351544
# Density public               0.945814       0.949546           -0.314269
# Infected per k               0.077049       0.060319           -0.366958
# Death per k                  0.110569       0.117516           -0.238309
#
#                     Density Business  Density horeca  Density public  \
# Total_reported              0.575487        0.551875        0.541091
# Deceased_till_2022          0.544175        0.532084        0.504463
# Population                  0.576169        0.550910        0.539017
# Residents per km²           0.959451        0.963832        0.945814
# Homes per km²               0.962052        0.965198        0.949546
# Surface area (km²)         -0.326408       -0.351544       -0.314269
# Density Business            1.000000        0.981949        0.982341
# Density horeca              0.981949        1.000000        0.954418
# Density public              0.982341        0.954418        1.000000
# Infected per k              0.104767        0.126328        0.093737
# Death per k                 0.106150        0.132444        0.093463
#
#                     Infected per k  Death per k
# Total_reported            0.088909    -0.010327
# Deceased_till_2022        0.087339     0.188722
# Population                0.051763    -0.019306
# Residents per km²         0.077049     0.110569
# Homes per km²             0.060319     0.117516
# Surface area (km²)       -0.366958    -0.238309
# Density Business          0.104767     0.106150
# Density horeca            0.126328     0.132444
# Density public            0.093737     0.093463
# Infected per k            1.000000     0.209942
# Death per k               0.209942     1.000000

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,6))
mask1 = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(),cmap='BuPu',mask=mask1, square=True, linewidth=0.1, fmt='.2f', annot=True)
# Out:
# <Axes: >

# %%
sns.lmplot(data=df,x='Homes per km²', y='Total_reported',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Homes per km²', y='Infected per k',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Density horeca', y='Infected per k',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Density public', y='Infected per k',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Homes per km²', y='Deceased_till_2022',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Homes per km²', y='Death per k',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Density horeca', y='Death per k',hue='Province',height=6, aspect=2)

# %%
sns.lmplot(data=df,x='Density public', y='Death per k',hue='Province',height=6, aspect=2)

# %% [markdown]
# <br><br/>

# %% [markdown]
# ## Interactive plots showing trends per province (Plotly)

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'colab'
fig = px.scatter(df,x='Homes per km²', y='Infected per k', hover_name='Municipality',trendline='ols',color='Province')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5256b791-679c-4f7e-a447-7c7061d178cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5256b791-679c-4f7e-a447-7c7061d178cd")) {                    Plotly.newPlot(                        "5256b791-679c-4f7e-a447-7c7061d178cd",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eInfected per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Groningen","Stadskanaal","Veendam","Pekela","Oldambt","Westerwolde","Midden-Groningen","Het Hogeland","Westerkwartier","Eemsdelta"],"legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Groningen","orientation":"v","showlegend":true,"x":[661.0,129.0,171.0,118.0,84.0,44.0,103.0,48.0,77.0,88.0],"xaxis":"x","y":[464,424,426,410,399,428,410,483,424,399],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eInfected per k = 0.0608749 * Homes per km\u00b2 + 417.429\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.166869\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eInfected per k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Groningen","showlegend":false,"x":[44.0,48.0,77.0,84.0,88.0,103.0,118.0,129.0,171.0,661.0],"xaxis":"x","y":[420.10724979116173,420.35074933719454,422.1161210459324,422.5422452514898,422.7857447975226,423.69886809514566,424.6119913927687,425.2816151443589,427.8383603777034,457.66705476672234],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eInfected per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Almere","Zeewolde","Noordoostpolder","Urk","Dronten","Lelystad"],"legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Flevoland","orientation":"v","showlegend":true,"x":[702.0,38.0,45.0,530.0,55.0,153.0],"xaxis":"x","y":[444,448,440,386,437,423],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eInfected per k = -0.0300618 * Homes per km\u00b2 + 437.297\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.142034\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eInfected per k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Flevoland","showlegend":false,"x":[38.0,45.0,55.0,153.0,530.0,702.0],"xaxis":"x","y":[436.1550033911341,435.9445708487189,435.643952930983,432.69789733717084,421.3646018385262,416.19397365346816],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Frysl\u00e2n\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eInfected per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Achtkarspelen","Ameland","Harlingen","Heerenveen","Leeuwarden","Ooststellingwerf","Opsterland","Schiermonnikoog","Smallingerland","Terschelling","Vlieland","Weststellingwerf","Tytsjerksteradiel","Dantumadiel","S\u00fadwest-Frysl\u00e2n","De Fryske Marren","Waadhoeke","Noardeast-Frysl\u00e2n"],"legendgroup":"Frysl\u00e2n","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Frysl\u00e2n","orientation":"v","showlegend":true,"x":[120.0, ...

# %%
fig = px.scatter(df,x='Homes per km²', y='Total_reported', hover_name='Municipality',trendline='ols',color='Province')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8a0ca47f-3514-4f9b-8e0c-7f88c9543813" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a0ca47f-3514-4f9b-8e0c-7f88c9543813")) {                    Plotly.newPlot(                        "8a0ca47f-3514-4f9b-8e0c-7f88c9543813",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eTotal_reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Groningen","Stadskanaal","Veendam","Pekela","Oldambt","Westerwolde","Midden-Groningen","Het Hogeland","Westerkwartier","Eemsdelta"],"legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Groningen","orientation":"v","showlegend":true,"x":[661.0,129.0,171.0,118.0,84.0,44.0,103.0,48.0,77.0,88.0],"xaxis":"x","y":[110430,13615,11773,5085,15563,11360,25230,23319,27561,18120],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eTotal_reported = 155.466 * Homes per km\u00b2 + 2528.13\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.872861\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eTotal_reported=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Groningen","showlegend":false,"x":[44.0,48.0,77.0,84.0,88.0,103.0,118.0,129.0,171.0,661.0],"xaxis":"x","y":[9368.63197593758,9990.4959842132,14499.010044211447,15587.272058693783,16209.136066969404,18541.12609800298,20873.116129036556,22583.24215179451,29112.81423868853,105291.15525245204],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eTotal_reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Almere","Zeewolde","Noordoostpolder","Urk","Dronten","Lelystad"],"legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Flevoland","orientation":"v","showlegend":true,"x":[702.0,38.0,45.0,530.0,55.0,153.0],"xaxis":"x","y":[98978,10615,21869,8433,19056,35100],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eTotal_reported = 77.9372 * Homes per km\u00b2 + 12558.8\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.438407\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eTotal_reported=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Flevoland","showlegend":false,"x":[38.0,45.0,55.0,153.0,530.0,702.0],"xaxis":"x","y":[15520.38320731318,16065.94375194086,16845.315958551833,24483.163583339363,53865.49577257303,67270.69772628175],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Frysl\u00e2n\u003cbr\u003eHomes per km\u00b2=%{x}\u003cbr\u003eTotal_reported=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Achtkarspelen","Ameland","Harlingen","Heerenveen","Leeuwarden","Ooststellingwerf","Opsterland","Schiermonnikoog","Smallingerland","Terschelling","Vlieland","Weststellingwerf","Tytsjerksteradiel","Dantumadiel","S\u00fadwest-Frysl\u00e2n","De Fryske Marren","Waadhoeke","Noardeast-Frysl\u00e2n"],"legendgroup":"Frysl\u00e2n","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Frysl\u00e2n","orientation":"v","sho ...

# %%
fig = px.scatter(df,x='Density Business', y='Infected per k', hover_name='Municipality',trendline='ols',color='Province')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8bac0be9-e86c-4fe5-8b1f-b29b4f89e730" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eDensity horeca=%{x}\u003cbr\u003eDeath per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Almere","Zeewolde","Noordoostpolder","Urk","Dronten","Lelystad"],"legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Flevoland","orientation":"v","showlegend":true,"x":[19.6,2.25,1.72,4.16,2.34,2.44],"xaxis":"x","y":[0.5968809603949288,0.8441668073611346,0.7842506384604556,1.0994548536350728,0.7340628082490308,1.120036611949466],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eDeath per k = -0.0167069 * Density horeca + 0.953666\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.316322\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eDensity horeca=%{x}\u003cbr\u003eDeath per k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Flevoland","showlegend":false,"x":[1.72,2.25,2.34,2.44,4.16,19.6],"xaxis":"x","y":[0.9249296863312967,0.9160750454071428,0.9145714271370035,0.9129007401701819,0.884164924340852,0.6262108566636116],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Frysl\u00e2n\u003cbr\u003eDensity horeca=%{x}\u003cbr\u003eDeath per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Achtkarspelen","Ameland","Harlingen","Heerenveen","Leeuwarden","Ooststellingwerf","Opsterland","Schiermonnikoog","Smallingerland","Terschelling","Vlieland","Weststellingwerf","Tytsjerksteradiel","Dantumadiel","S\u00fadwest-Frysl\u00e2n","De Fryske Marren","Waadhoeke" ...

# %%
fig = px.scatter(df,x='Density public', y='Death per k', hover_name='Municipality',trendline='ols', color='Province')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d030b37b-2a5b-4ab3-995d-116eb09e787c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d030b37b-2a5b-4ab3-995d-116eb09e787c")) {                    Plotly.newPlot(                        "d030b37b-2a5b-4ab3-995d-116eb09e787c",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eDensity public=%{x}\u003cbr\u003eDeath per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Groningen","Stadskanaal","Veendam","Pekela","Oldambt","Westerwolde","Midden-Groningen","Het Hogeland","Westerkwartier","Eemsdelta"],"legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Groningen","orientation":"v","showlegend":true,"x":[28.87,3.71,5.21,2.59,1.93,1.46,3.31,0.89,3.2,1.68],"xaxis":"x","y":[0.34012605659529616,0.7779679477205539,0.7242178447276941,1.2092873266688164,1.024485196188915,0.9420808682217281,0.8122948955388765,0.8488964346349746,0.6004988759892834,0.7049389787196546],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eDeath per k = -0.0200584 * Density public + 0.904488\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.501728\u003cbr\u003e\u003cbr\u003eProvince=Groningen\u003cbr\u003eDensity public=%{x}\u003cbr\u003eDeath per k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Groningen","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Groningen","showlegend":false,"x":[0.89,1.46,1.68,1.93,2.59,3.2,3.31,3.71,5.21,28.87],"xaxis":"x","y":[0.8866361853312408,0.8752028876262403,0.8707900358804506,0.8657754316238715,0.8525368763865024,0.8403012420004493,0.8380948161275544,0.8300714493170278,0.7999838237775527,0.3254016769349003],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eDensity public=%{x}\u003cbr\u003eDeath per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Almere","Zeewolde","Noordoostpolder","Urk","Dronten","Lelystad"],"legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Flevoland","orientation":"v","showlegend":true,"x":[22.89,1.97,1.49,2.1,1.85,2.23],"xaxis":"x","y":[0.5968809603949288,0.8441668073611346,0.7842506384604556,1.0994548536350728,0.7340628082490308,1.120036611949466],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eDeath per k = -0.014787 * Density public + 0.943312\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.371033\u003cbr\u003e\u003cbr\u003eProvince=Flevoland\u003cbr\u003eDensity public=%{x}\u003cbr\u003eDeath per k=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Flevoland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Flevoland","showlegend":false,"x":[1.49,1.85,1.97,2.1,2.23,22.89],"xaxis":"x","y":[0.9212796699268905,0.9159563497817421,0.9141819097333592,0.9122595996809446,0.9103372896285299,0.6048378612986232],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProvince=Frysl\u00e2n\u003cbr\u003eDensity public=%{x}\u003cbr\u003eDeath per k=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Achtkarspelen","Ameland","Harlingen","Heerenveen","Leeuwarden","Ooststellingwerf","Opsterland","Schiermonnikoog","Smallingerland","Terschelling","Vlieland","Weststellingwerf","Tytsjerksteradiel","Dantumadiel","S\u00fadwest-Frysl\u00e2n","De Fryske Marren","Waadhoeke"," ...

# %% [markdown]
# ##Hypothesis testing： regression analysis

# %% [markdown]
# From the plots above we can tell that there is not apparent relevance between COVID infections/deaths and the densities of homes, business and public service.
# The number of infected/deceased cases does not rise accordingly when the density of urban elements increases; in certain
